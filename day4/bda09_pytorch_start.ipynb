# %% [markdown]
# ### PyTorch
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c6/PyTorch_logo_black.svg/1920px-PyTorch_logo_black.svg.png" width="700" style="background:white">
#
# - https://pytorch.org/ 공식사이트
# - https://pytorch.kr/ 한글 공식사이트
# - https://tutorials.pytorch.kr/ 튜토리얼만 한글화 사이트
# -

# %% [markdown]
# #### PyTorch 설치
# - CPU 설치
#     - 간단하지만, 그래픽카드 가속 사용할 수 없음
#     - 기본 파이썬 환경 설치
#
# - GPU 설치
#     - 가상환경 생성, 설치
#
# ##### CPU 설치
# - https://pytorch.org/get-started/locally/ 나와있는 Note에서 해당 플랫폼 종류 선택, 명령어 복사 후 실행
#
# ```python
# !pip install torch torchvision torchaudio
# ```

# %%
# !pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.4.0-cp311-cp311-win_amd64.whl.metadata (27 kB)
# Collecting torchvision
#   Downloading torchvision-0.19.0-1-cp311-cp311-win_amd64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.4.0-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in c:\dev\langs\python311\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\dev\langs\python311\lib\site-packages (from torch) (4.9.0)
# Collecting sympy (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in c:\dev\langs\python311\lib\site-packages (from torch) (3.1.3)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2 in c:\dev\langs\python311\lib\site-packages (from torchvision) (1.26.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\dev\langs\python311\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\langs\python311\lib\site-packages (from jinja2->torch) (2.1.4)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading torch-2.4.0-cp311-cp311-win_amd64.whl (197.9 MB)
#    ---------------------------------------- 0.0/197.9 MB ? eta -:--:--
#    ---------------------------------------- 1.6/197.9 MB 9.3 MB/s eta 0:00:22
#     --------------------------------------- 3.7/197.9 MB 9.5 MB/s eta 0:00:21
#    - -------------------------------------- 5.8/197.9 MB 10.1 MB/s eta 0:00:20
#    - -------------------------------------- 8.1/197.9 MB 10.1 MB/s eta 0:00:19
#    -- ------------------------------------- 10.5/197.9 MB 10.2 MB/s eta 0:00:19
#    -- ------------------------------------- 12.8/197.9 MB 10.5 MB/s eta 0:00:18
#    -- ------------------------------------- 14.7/197.9 MB 10.1 MB/s eta 0:00:19
#    --- ------------------------------------ 16.8/197.9 MB 10.1 MB/s eta 0:00:18
#    --- ------------------------------------ 18.9/197.9 MB 10.1 MB/s eta 0:00:18
#    ---- ----------------------------------- 20.7/197.9 MB 10.1 MB/s eta 0:00:18
#    ---- ----------------------------------- 22.8/197.9 MB 10.0 MB/s eta 0:00:18
#    ----- ---------------------------------- 24.9/197.9 MB 10.1 MB/s eta 0:00:18
#    ----- ---------------------------------- 27.3/197.9 MB 10.1 MB/s eta 0:00:17
#    ----- ---------------------------------- 29.1/197.9 MB 10.0 MB/s eta 0:00:17
#    ------ --------------------------------- 30.7/197.9 MB 9.9 MB/s eta 0:00:17
#    ------ --------------------------------- 32.5/197.9 MB 9.8 MB/s eta 0:00:17
#    ------ --------------------------------- 34.6/197.9 MB 9.8 MB/s eta 0:00:17
#    ------- -------------------------------- 35.9/197.9 MB 9.7 MB/s eta 0:00:17
#    ------- -------------------------------- 38.0/197.9 MB 9.7 MB/s eta 0:00:17
#    -------- ------------------------------- 40.1/197.9 MB 9.6 MB/s eta 0:00:17
#    -------- ------------------------------- 41.7/197.9 MB 9.5 MB/s eta 0:00:17
1 MB/s eta 0:00:03
#    ----------------------------------- ---- 176.4/197.9 MB 8.1 MB/s eta 0:00:03
#    ------------------------------------ --- 178.8/197.9 MB 8.1 MB/s eta 0:00:03
#    ------------------------------------ --- 180.6/197.9 MB 8.1 MB/s eta 0:00:03
#    ------------------------------------ --- 182.5/197.9 MB 8.1 MB/s eta 0:00:02
#    ------------------------------------- -- 184.0/197.9 MB 8.2 MB/s eta 0:00:02
#    ------------------------------------- -- 185.6/197.9 MB 8.1 MB/s eta 0:00:02
#    ------------------------------------- -- 186.9/197.9 MB 8.1 MB/s eta 0:00:02
#    -------------------------------------- - 188.2/197.9 MB 8.1 MB/s eta 0:00:02
#    -------------------------------------- - 189.5/197.9 MB 8.1 MB/s eta 0:00:02
#    -------------------------------------- - 191.1/197.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  192.9/197.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  194.5/197.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  196.3/197.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  197.7/197.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  197.7/197.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 197.9/197.9 MB 8.0 MB/s eta 0:00:00
# Downloading torchvision-0.19.0-1-cp311-cp311-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 9.3 MB/s eta 0:00:00
# Downloading torchaudio-2.4.0-cp311-cp311-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ------------------------------ --------- 1.8/2.4 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 7.7 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 11.5 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ----------- ---------------------------- 1.8/6.2 MB 9.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.4/6.2 MB 8.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.2 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 8.4 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy, networkx, fsspec, torch, torchvision, torchaudio
# Successfully installed fsspec-2024.6.1 mpmath-1.3.0 networkx-3.3 sympy-1.13.1 torch-2.4.0 torchaudio-2.4.0 torchvision-0.19.0

# %%
import torch

# %%
## 2.4.0+cpu = CPU 용 설치
torch.__version__
# Out:
# '2.4.0+cpu'

# %% [markdown]
# ##### PyTorch GPU 설치
# - NVIDIA GPU에서만 가능, CUDA로 되어있기 때문
# - GPU 설치가 가능한지 먼저 확인
#
# ```python
# !nvidia-smi
# ```

# %%
# !nvidia-smi
# Out:
# Tue Aug  6 12:31:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.23                 Driver Version: 536.23       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  | 00000000:01:00.0  On |                  N/A |
# | 50%   33C    P5              13W /  75W |    754MiB /  4096MiB |      3%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      3100    C+G   ...n\126.0.2592.113\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A      6540    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A      7860    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A      8284    C+G   ...n\126.0.2592.113\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A      8684    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A      8708    C+G   ...2txyewy\StartMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A      9344    C+G   C:\dev\IDE\Microsoft VS Code\Code.exe     N/A      |
# |    0   N/A  N/A      9644    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     10444    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     11812    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     12496    C+G   ...5n1h2txyewy\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     13912    C+G   ....5536.0_x64__8j3eq9eme6ctt\IGCC.exe    N/A      |
# |    0   N/A  N/A     14544    C+G   ...n\126.0.2592.113\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     15784    C+G   ...Desktop\app-3.4.2\GitHubDesktop.exe    N/A      |
# |    0   N/A  N/A     16440    C+G   ...r\AppData\Roaming\Zoom\bin\Zoom.exe    N/A      |
# +---------------------------------------------------------------------------------------+
